# %% [markdown]
# <a href="https://colab.research.google.com/github/ramiromotajunior-glitch/atividade-01-pyton/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome=input("digite o seu nome:")
print("o seu nome e:",nome)
# Out:
# digite o seu nome:felipe
# o seu nome e: felipe

# %%
valor1=int(input("digite seu valor:"))
valor2=int(input("digite o seu nome:"))
resultado = valor1 + valor2
print(resultado)
# Out:
# digite seu valor:10
# digite o seu nome:10
# 20

# %%
#atividade 03
valor = int(input('digite o se valor1:'))
valor2 = int(input('digite o seu valor2'))
soma = valor + valor2
subtracao=valor-valor2
mult= valor*valor2
div=valor/valor2
print(soma)
print(subtracao)
print(mult)
print(div)
# Out:
# digite o se valor1:50
# digite o seu valor22
# 52
# 48
# 100
# 25.0

# %%
usuario = input("digite seu nome:")
print("ola",usuario,"seja bem vindo!")
# Out:
# digite seu nome:Ramiro
# ola Ramiro seja bem vindo!
